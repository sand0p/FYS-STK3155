# %% [markdown]
# ## Testing sigmoid as activation function, different architectures

# %%
from util import *
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(2025)
n_points = 1000

noise = 0.01 * np.random.randn(n_points,1)
x = np.linspace(-1, 1, n_points).reshape(-1,1)
y = Runge(x) + noise

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
scaler = StandardScaler()
scaler.fit(x_train)
x_train_s = scaler.transform(x_train)
x_test_s = scaler.transform(x_test)
y_offset = np.mean(y_test)

n_hidden_layers = [1, 2, 3, 4]
layer_nodes = [2, 10, 50, 100]
sigmoid_mses = np.zeros((len(n_hidden_layers), len(layer_nodes)))
sigmoid_r2s = np.zeros((len(n_hidden_layers), len(layer_nodes)))

for i, n_layers in enumerate(n_hidden_layers):
	for j, n_nodes in enumerate(layer_nodes):
		print(f"Training NN with {n_layers} hidden layers and {n_nodes} nodes per layer")

		layer_output_sizes = [n_nodes]*n_layers + [1]
		activation_funcs = [sigmoid]*(n_layers) + [linear]
		activation_ders = [sigmoid_der]*(n_layers) + [linear_der]
		cost_fun = MSE
		cost_der = MSE_der

		nn = NeuralNetwork(1, layer_output_sizes, activation_funcs, activation_ders, cost_fun, cost_der)
		nn.ADAM_stochastic(x_train_s, y_train - y_offset, learning_rate = 0.001, rho1 = 0.9, rho2 = 0.999, epochs = 500, minibatch_size=5)
		nn_pred = nn.predict_batch(x_test_s) + y_offset 
		mse = mean_squared_error(y_test, nn_pred)
		r2 = r2_score(y_test, nn_pred)
		sigmoid_mses[i, j] = mse
		sigmoid_r2s[i, j] = r2
		print("MSE:", mse, "R2:", r2, "\n")

plt.figure()
sns.heatmap(sigmoid_mses, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title("MSE for different NN architectures with Sigmoid activation")
plt.show()

plt.figure()
sns.heatmap(sigmoid_r2s, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title(r"$R^2$ for different NN architectures with Sigmoid activation")
plt.show()

# %% [markdown]
# ## ReLU as activation function

# %%
from util import *
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(2025)
n_points = 1000

noise = 0.01 * np.random.randn(n_points,1)
x = np.linspace(-1, 1, n_points).reshape(-1,1)
y = Runge(x) + noise

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
scaler = StandardScaler()
scaler.fit(x_train)
x_train_s = scaler.transform(x_train)
x_test_s = scaler.transform(x_test)
y_offset = np.mean(y_test)

n_hidden_layers = [1, 2, 3, 4]
layer_nodes = [2,10, 50, 100]
ReLU_mses = np.zeros((len(n_hidden_layers), len(layer_nodes)))
ReLU_r2s = np.zeros((len(n_hidden_layers), len(layer_nodes)))

for i, n_layers in enumerate(n_hidden_layers):
	for j, n_nodes in enumerate(layer_nodes):
		print(f"Training NN with {n_layers} hidden layers and {n_nodes} nodes per layer")

		layer_output_sizes = [n_nodes]*n_layers + [1]
		activation_funcs = [ReLU]*(n_layers) + [linear]
		activation_ders = [ReLU_der]*(n_layers) + [linear_der]
		cost_fun = MSE
		cost_der = MSE_der

		nn = NeuralNetwork(1, layer_output_sizes, activation_funcs, activation_ders, cost_fun, cost_der)
		nn.ADAM_stochastic(x_train_s, y_train - y_offset, learning_rate = 0.001, rho1 = 0.9, rho2 = 0.999, epochs = 500, minibatch_size=5)
		nn_pred = nn.predict_batch(x_test_s) + y_offset 
		mse = mean_squared_error(y_test, nn_pred)
		r2 = r2_score(y_test, nn_pred)
		ReLU_mses[i, j] = mse
		ReLU_r2s[i, j] = r2
		print("MSE:", mse, "R2:", r2, "\n")

plt.figure()
sns.heatmap(ReLU_mses, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title("MSE for different NN architectures with ReLU activation")
plt.show()

plt.figure()
sns.heatmap(ReLU_r2s, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title(r"$R^2$ for different NN architectures with ReLU activation")
plt.show()

# %% [markdown]
# ## Leaky ReLU as activation function

# %%
from util import *
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

np.random.seed(2025)
n_points = 1000

noise = 0.01 * np.random.randn(n_points,1)
x = np.linspace(-1, 1, n_points).reshape(-1,1)
y = Runge(x) + noise

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
scaler = StandardScaler()
scaler.fit(x_train)
x_train_s = scaler.transform(x_train)
x_test_s = scaler.transform(x_test)
y_offset = np.mean(y_test)

n_hidden_layers = [1, 2, 3, 4]
layer_nodes = [2,10, 50, 100]
leaky_ReLU_mses = np.zeros((len(n_hidden_layers), len(layer_nodes)))
leaky_ReLU_r2s = np.zeros((len(n_hidden_layers), len(layer_nodes)))

for i, n_layers in enumerate(n_hidden_layers):
	for j, n_nodes in enumerate(layer_nodes):
		print(f"Training NN with {n_layers} hidden layers and {n_nodes} nodes per layer")

		layer_output_sizes = [n_nodes]*n_layers + [1]
		activation_funcs = [leaky_ReLU]*(n_layers) + [linear]
		activation_ders = [leaky_ReLU_der]*(n_layers) + [linear_der]
		cost_fun = MSE
		cost_der = MSE_der

		nn = NeuralNetwork(1, layer_output_sizes, activation_funcs, activation_ders, cost_fun, cost_der)
		nn.ADAM_stochastic(x_train_s, y_train - y_offset, learning_rate = 0.001, rho1 = 0.9, rho2 = 0.999, epochs = 500, minibatch_size=5)
		nn_pred = nn.predict_batch(x_test_s) + y_offset 
		mse = mean_squared_error(y_test, nn_pred)
		r2 = r2_score(y_test, nn_pred)
		leaky_ReLU_mses[i, j] = mse
		leaky_ReLU_r2s[i, j] = r2
		print("MSE:", mse, "R2:", r2, "\n")

plt.figure()
sns.heatmap(leaky_ReLU_mses, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title("MSE for different NN architectures with Leaky ReLU activation")
plt.show()

plt.figure()
sns.heatmap(leaky_ReLU_r2s, xticklabels=layer_nodes, yticklabels=n_hidden_layers, annot=True, fmt=".4f")
plt.xlabel("Number of nodes per hidden layer")
plt.ylabel("Number of hidden layers")
plt.title(r"$R^2$ for different NN architectures with Leaky ReLU activation")
plt.show()
